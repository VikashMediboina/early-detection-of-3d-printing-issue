# %%
import torch
from torch import nn
import torch.nn.functional as F
from sklearn.metrics import f1_score, accuracy_score
from tqdm import tqdm
import cached_dataloader
from PIL import Image

from transformers import ViTForImageClassification, ViTFeatureExtractor, ViTImageProcessor, ViTModel
from sklearn.metrics import f1_score, accuracy_score
from tqdm import tqdm

# %%
# global variables
BATCH_SIZE = 64
TRAIN_SPLIT = 0.9
MLP_HIDDEN_SIZES = [1024,512,256]
DROPOUT_PROB = [0, 0, 0]
LR = 0.1
MOMENTUM = 0.9
model_vit = ViTModel.from_pretrained('google/vit-base-patch16-224-in21k')
img_processor = ViTImageProcessor.from_pretrained('google/vit-base-patch16-224-in21k')

configuration={}
configuration['Models']={}
configuration['Models']['mlp_num_classes']=2
configuration['Models']['mlp_hidden_sizes']= [1024,512,256]
configuration['Models']['mlp_dropout_prob']=[0.5,0.5,0.4]
configuration['Models']['encoder_finetuning']=True
configuration['Models']['image_processor']=img_processor
configuration['Dataset']={}
configuration['Dataset']['batch_size']=BATCH_SIZE


device = torch.device("cuda" if torch.cuda.is_available() else "mps")
print(device)
train_dataset, val_dataset = cached_dataloader.getData(BATCH_SIZE, TRAIN_SPLIT)



for x in train_dataset:
    print(type(x))
    break

for x in val_dataset:
    print(type(x))
    break
# Out:
# mps
# <class 'tuple'>
# <class 'tuple'>

# %%
class MLP(nn.Module):
    def __init__(self, in_channels, num_classes, hidden_sizes=[128, 64], dropout_probability=[0.5,0.7]):
        super(MLP, self).__init__()
        assert len(hidden_sizes) >= 1 , "specify at least one hidden layer"
        
        self.layers = self.create_layers(in_channels, num_classes, hidden_sizes, dropout_probability)


    def create_layers(self, in_channels, num_classes, hidden_sizes, dropout_probability):
        layers = []
        layer_sizes = [in_channels] + hidden_sizes + [num_classes]
        for i in range(len(layer_sizes)-1):
            layers.append(nn.Linear(layer_sizes[i], layer_sizes[i+1]))
            if i < len(layer_sizes)-2:
                layers.append(nn.BatchNorm1d(layer_sizes[i+1]))
                layers.append(nn.ReLU())
                layers.append(nn.Dropout(dropout_probability[i]))
            else:
                layers.append(nn.Softmax(dim=1))
        return nn.Sequential(*layers)

    def forward(self, x):
        out = x.view(x.shape[0], -1)
        out = self.layers(out)
        return out

# %%
class CombinedModel(nn.Module):
    def __init__(self, modality1, configuration,device):
        super().__init__()
        self.device = device
        self.modality1 = modality1.to(self.device)
        self.config = configuration

        self.head = MLP(in_channels=self._calculate_in_features(),
                            num_classes=self.config['Models']['mlp_num_classes'],
                            hidden_sizes=self.config['Models']['mlp_hidden_sizes'], 
                            dropout_probability= self.config['Models']['mlp_dropout_prob']).to(self.device)

        if(configuration['Models']['encoder_finetuning'] == False):
            for param in self.modality1.parameters():
                param.requires_grad = False

  

        for param in self.head.parameters():
            param.requires_grad = True

    def forward(self, input1):
        image_output = self.modality1(input1)['last_hidden_state'].to(self.device)
        image_output = torch.nn.Flatten()(image_output).to(self.device)
        head_output = self.head(image_output).to(self.device)
        return head_output

    def _calculate_in_features(self):
        # Create an example input and pass it through the network to get the output size
        image_list=[]
        img_batch = torch.randint(0, 255, size=(self.config['Dataset']['batch_size'], 3, 224, 224)).float()
        image_list.extend([image for image in img_batch])
        img_processor = self.config['Models']['image_processor']
        input1 = img_processor(image_list, return_tensors='pt').to(self.device) 
        image_output = self.modality1(**input1)['last_hidden_state'].to(self.device)
        image_output = torch.nn.Flatten()(image_output).to(self.device)
        return image_output.shape[1]

# %%
model=CombinedModel(model_vit,configuration,device)



# Define the loss function and optimizer
loss_function = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)

# %%
# Define the training loop
num_epochs = 10
for epoch in range(num_epochs):
    model.train()
    train_loss = 0.0
    train_accuracy = 0.0
    train_f1 = 0.0
    image_list = []
    for i, (images, labels) in tqdm(enumerate(train_dataset), total = len(train_dataset), desc=f"[Epoch {epoch}]",ascii=' >='):
        image_list.extend([image for image in images])
        labels = labels.to(device)
        processed_imgs = img_processor(image_list, return_tensors='pt', data_format='channels_first').to(device)
        outputs = model(processed_imgs['pixel_values'])
        loss = loss_function(outputs, labels)
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
        image_list = []
        train_loss += loss.item()
        _, preds = torch.max(outputs, dim=1)
        train_accuracy += accuracy_score(labels.cpu(), preds.cpu())
        train_f1 += f1_score(labels.cpu(), preds.cpu(), average='macro')
        
    train_loss /= len(train_dataset)
    train_accuracy /= len(train_dataset)
    train_f1 /= len(train_dataset)
    
    model.eval()
    val_loss = 0.0
    val_accuracy = 0.0
    val_f1 = 0.0
    with torch.no_grad():
        for j, (images, labels) in tqdm(enumerate(val_dataset), total = len(val_dataset), desc=f"[Epoch {epoch}]",ascii=' >='):
            image_list.extend([image for image in images])
            labels = labels.to(device)
            processed_imgs = img_processor(image_list, return_tensors='pt', data_format='channels_first').to(device)
            outputs = model(processed_imgs['pixel_values'])
            loss = loss_function(outputs, labels)
            image_list = []
            val_loss += loss.item()
            _, preds = torch.max(outputs, dim=1)
            val_accuracy += accuracy_score(labels.cpu(), preds.cpu())
            val_f1 += f1_score(labels.cpu(), preds.cpu(), average='macro')
    
    val_loss /= len(val_dataset)
    val_accuracy /= len(val_dataset)
    val_f1 /= len(val_dataset)
    
    print(f"Epoch {epoch+1} | Train loss: {train_loss:.4f} | Train accuracy: {train_accuracy:.4f} | Train F1-score: {train_f1:.4f} | Validation loss: {val_loss:.4f} | Validation accuracy: {val_accuracy:.4f} | Validation F1-score: {val_f1:.4f}")
# Create some sample input data
input_data = torch.randn(BATCH_SIZE,3,224,224).to(device)
# Out:
# [Epoch 0]: 100%|==========| 1140/1140 [45:27<00:00,  2.39s/it]
# [Epoch 0]: 100%|==========| 127/127 [02:39<00:00,  1.26s/it]
# Epoch 1 | Train loss: 0.4016 | Train accuracy: 0.9394 | Train F1-score: 0.9383 | Validation loss: 0.8573 | Validation accuracy: 0.4559 | Validation F1-score: 0.3119
# [Epoch 1]: 100%|==========| 1140/1140 [37:02<00:00,  1.95s/it]
# [Epoch 1]: 100%|==========| 127/127 [01:44<00:00,  1.21it/s]
# Epoch 2 | Train loss: 0.3381 | Train accuracy: 0.9845 | Train F1-score: 0.9841 | Validation loss: 0.5370 | Validation accuracy: 0.7476 | Validation F1-score: 0.7371
# [Epoch 2]: 100%|==========| 1140/1140 [40:24<00:00,  2.13s/it]
# [Epoch 2]: 100%|==========| 127/127 [01:38<00:00,  1.28it/s]
# Epoch 3 | Train loss: 0.3278 | Train accuracy: 0.9902 | Train F1-score: 0.9899 | Validation loss: 0.4170 | Validation accuracy: 0.9103 | Validation F1-score: 0.9088
# [Epoch 3]: 100%|==========| 1140/1140 [36:21<00:00,  1.91s/it]
# [Epoch 3]: 100%|==========| 127/127 [01:39<00:00,  1.28it/s]
# Epoch 4 | Train loss: 0.3228 | Train accuracy: 0.9933 | Train F1-score: 0.9931 | Validation loss: 0.7692 | Validation accuracy: 0.5441 | Validation F1-score: 0.3513
# [Epoch 4]: 100%|==========| 1140/1140 [2:46:40<00:00,  8.77s/it]
# [Epoch 4]: 100%|==========| 127/127 [01:47<00:00,  1.18it/s]
# Epoch 5 | Train loss: 0.3199 | Train accuracy: 0.9951 | Train F1-score: 0.9949 | Validation loss: 0.7692 | Validation accuracy: 0.5441 | Validation F1-score: 0.3513
# [Epoch 5]:  81%|========  | 927/1140 [40:41<09:20,  2.63s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 13
#      11 labels = labels.to(device)
#      12 processed_imgs = img_processor(image_list, return_tensors='pt', data_format='channels_first').to(device)
# ---> 13 outputs = model(processed_imgs['pixel_values'])
#      14 loss = loss_function(outputs, labels)
#      15 loss.backward()
#
# File ~/mambaforge/envs/printing/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In[4], line 23, in CombinedModel.forward(self, input1)
#      22 def forward(self, input1):
# ---> 23     image_output = self.modality1(input1)['last_hidden_state'].to(self.device)
#      24     image_output = torch.nn.Flatten()(image_output).to(self.device)
#      25     head_output = self.head(image_output).to(self.device)
#
# File ~/mambaforge/envs/printing/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/mambaforge/envs/printing/lib/python3.10/site-packages/transformers/models/vit/modeling_vit.py:587, in ViTModel.forward(self, pixel_values, bool_masked_pos, head_mask, output_attentions, output_hidden_states, interpolate_pos_encoding, return_dict)
#     581     pixel_values = pixel_values.to(expected_dtype)
#     583 embedding_output = self.embeddings(
#     584     pixel_values, bool_masked_pos=bool_masked_pos, interpolate_pos_encoding=interpolate_pos_encoding
#     585 )
# --> 587 encoder_outputs = self.encoder(
#     588     embedding_output,
#     589     head_mask=head_mask,
#     590     output_attentions=output_attentions,
#     591     output_hidden_states=output_hidden_states,
#     592     return_dict=return_dict,
#     593 )
#     594 sequence_output = encoder_outputs[0]
#     595 sequence_output = self.layernorm(sequence_output)
#
# File ~/mambaforge/envs/printing/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/mambaforge/envs/printing/lib/python3.10/site-packages/transformers/models/vit/modeling_vit.py:413, in ViTEncoder.forward(self, hidden_states, head_mask, output_attentions, output_hidden_states, return_dict)
#     407     layer_outputs = torch.utils.checkpoint.checkpoint(
#     408         create_custom_forward(layer_module),
#     409         hidden_states,
#     410         layer_head_mask,
#     411     )
#     412 else:
# --> 413     layer_outputs = layer_module(hidden_states, layer_head_mask, output_attentions)
#     415 hidden_states = layer_outputs[0]
#     417 if output_attentions:
#
# File ~/mambaforge/envs/printing/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/mambaforge/envs/printing/lib/python3.10/site-packages/transformers/models/vit/modeling_vit.py:365, in ViTLayer.forward(self, hidden_states, head_mask, output_attentions)
#     363 # in ViT, layernorm is also applied after self-attention
#     364 layer_output = self.layernorm_after(hidden_states)
# --> 365 layer_output = self.intermediate(layer_output)
#     367 # second residual connection is done here
#     368 layer_output = self.output(layer_output, hidden_states)
#
# File ~/mambaforge/envs/printing/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/mambaforge/envs/printing/lib/python3.10/site-packages/transformers/models/vit/modeling_vit.py:312, in ViTIntermediate.forward(self, hidden_states)
#     311 def forward(self, hidden_states: torch.Tensor) -> torch.Tensor:
# --> 312     hidden_states = self.dense(hidden_states)
#     313     hidden_states = self.intermediate_act_fn(hidden_states)
#     315     return hidden_states
#
# File ~/mambaforge/envs/printing/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/mambaforge/envs/printing/lib/python3.10/site-packages/torch/nn/modules/linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
# Specify the file path where the model is saved
file_path = 'modelvision.pth'

# Load the state dictionary from the saved file
torch.save(model.state_dict(), file_path)

# %%
file_path = 'modelvision.pth'
model_train = CombinedModel(model_vit,configuration,device)

model_train.load_state_dict(torch.load(file_path))
# Out:
# <All keys matched successfully>

# %%
import pandas as pd

# %%
test_data = pd.read_csv("/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/test.csv")
test_data["img_path"]= ["/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/" + each for each in test_data["img_path"]]

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "mps")
print(device)
# Out:
# mps

# %%
from sklearn.metrics import f1_score, accuracy_score

# Define the ViT model and feature extractor
img_processor = ViTImageProcessor.from_pretrained('google/vit-base-patch16-224-in21k')

# Define the device to train the model on
device = torch.device("cuda" if torch.cuda.is_available() else "mps")
# trained_model = model_train.to(device)
model_train.to(device).eval()
predicted_labels=[] 
submission = {}
# Define the testing loop
with torch.no_grad():
    for image_path in test_data["img_path"]:
        image = Image.open(image_path).convert("RGB")
        processed_img = img_processor(image, return_tensors='pt', data_format='channels_first').to(device)
        outputs = model_train(processed_img['pixel_values'])
        # print(outputs)
        # preds_probs = outputs.prediction.softmax(dim=-1)
        preds = torch.argmax(torch.softmax(outputs, dim=1),axis=1)

        # print(preds)
        predicted_labels.append(preds.item())
        # print(preds.item())
        submission[image_path] = preds.item()

# %%
# test_data["img_path"]
test_data['new_column'] = test_data['img_path'].str.slice(77)
submission
# Out:
# {'/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578538.704966.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578539.108019.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578539.512872.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578539.916711.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578540.329089.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578540.731776.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578541.134508.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578541.539697.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578541.946032.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578542.346133.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578542.764537.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578543.172368.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578543.5863.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578544.006929.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578544.411404.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578544.833467.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578545.250962.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578545.672642.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578546.074281.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578546.491387.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578546.896918.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578547.320248.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578547.72799.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578548.146402.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578548.548827.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578548.972845.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578549.387781.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578549.802648.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578550.207722.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578550.628724.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578551.0409.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578551.462157.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578551.87371.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578552.281372.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578552.688239.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578553.112066.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578553.526195.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578553.931534.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578554.353903.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578554.755084.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578555.16281.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578555.579155.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578555.994419.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578556.39891.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578556.821764.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578557.244942.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578557.666633.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578558.081008.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578558.504981.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578558.914262.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578559.324585.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578559.747285.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578560.149259.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578560.561309.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578560.97434.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578561.374425.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578561.798866.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578562.212455.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578562.618928.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578563.019558.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578563.442774.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578563.848197.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578564.249424.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578564.666611.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578565.072252.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578565.491934.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578565.89435.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578566.297309.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578566.70002.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578567.104066.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578567.510908.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578567.91737.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578568.317742.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578568.721302.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578569.125683.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578569.543236.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578569.95623.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578570.370892.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578570.773047.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578571.195793.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578571.615069.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578572.016122.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578572.416432.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578572.817853.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578573.220505.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578573.643911.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578574.044853.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578574.447922.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578574.870847.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578575.290899.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578575.692278.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578576.095671.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578576.518162.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578576.933134.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578577.337695.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578577.738636.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578578.143888.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578578.544236.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578578.949339.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578579.370397.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578579.787941.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578580.190532.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578580.592937.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578580.993034.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578581.403878.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578581.818204.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578582.238084.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578582.645844.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578583.053659.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578583.471363.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578583.879828.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578584.298283.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578584.714007.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578585.1252.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578585.54066.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578585.950206.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578586.352513.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578586.757843.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578587.15868.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578587.576671.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578587.978348.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578588.380908.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578588.784276.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578589.207597.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578589.625691.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578590.027328.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578590.432571.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578590.836347.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578591.257642.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578591.675956.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578592.076735.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578592.478759.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578592.898146.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578593.320762.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578593.722937.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578594.123748.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678578594.525291.jpg': 1,
#  '/Users/vikashmediboina/Downloads/early-detection-of-3d-printing-issues/images/101/1678578332/1678